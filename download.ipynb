# %%
import os
os.environ['KAGGLE_USERNAME'] = "jenyuanhuang"
os.environ['KAGGLE_KEY'] = "ccf82ca092664473a870022d7ae46c2c"

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
training_files = api.competition_list_files('imagenet-object-localization-challenge/data')
for file in training_files:
    print(file.name)
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 training_files = api.competition_list_files('imagenet-object-localization-challenge/data')
#       2 for file in training_files:
#       3     print(file.name)
#
# File ~/miniconda3/envs/edm/lib/python3.9/site-packages/kaggle/api/kaggle_api_extended.py:874, in KaggleApi.competition_list_files(self, competition)
#     867 def competition_list_files(self, competition):
#     868     """ list files for competition
#     869          Parameters
#     870         ==========
#     871         competition: the name of the competition
#     872     """
#     873     competition_list_files_result = self.process_response(
# --> 874         self.competitions_data_list_files_with_http_info(id=competition))
#     875     return [File(f) for f in competition_list_files_result]
#
# ...
