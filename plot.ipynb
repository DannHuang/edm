# %%
import matplotlib.pyplot as plt

def plot_floats(init_value, float_list, float_list_2, float_list_3, target, joint):
    index = [i for i in range(len(float_list))]
    plt.plot(index, init_value)
    plt.plot(index, float_list)
    plt.plot(index, float_list_2)
    plt.plot(index, float_list_3)
    plt.plot(index, target)
    plt.plot(index, joint)
    plt.xlabel('Step')
    plt.ylabel('Sigma')
    plt.title('Plot of Floats')
    plt.show()

# Plot sigmas
init=[80.0, 56.80489730834961, 38.591888427734375, 24.758621215820312, 14.702751159667969, 7.821922302246094, 3.5137786865234375, 1.1759719848632812, 0.20616912841796875, 0.0019989013671875, 0.0]
sigmas = [80.0, 42.25395965576172, 13.870674133300781, 2.9344711303710938, 0.9048233032226562, 0.3139190673828125, 0.11188507080078125, 0.0382080078125, 0.01123046875, 0.00199127197265625, 0.0]
sigmas_2 = [80.0, 24.264205932617188, 4.3195343017578125, 1.3639297485351562, 0.5013809204101562, 0.194122314453125, 0.07355499267578125, 0.02645111083984375, 0.0079498291015625, 0.0019989013671875, 0.0]
sigmas_3 = [80.0, 14.601509094238281, 3.3031539916992188, 1.1205520629882812, 0.425048828125, 0.16886138916015625, 0.06551361083984375, 0.02371978759765625, 0.00711822509765625, 0.0019989013671875, 0.0]
target = [80.0, 6.722320556640625, 2.137908935546875, 0.83740234375, 0.34935760498046875, 0.146026611328125, 0.06162261962890625, 0.02414703369140625, 0.0078125, 0.00200653076171875, 0.0]
joint = [80.0, 22.017372131347656, 6.928871154785156, 2.4451446533203125, 0.9098663330078125, 0.3449249267578125, 0.1280364990234375, 0.0438385009765625, 0.01238250732421875, 0.0019989013671875, 0.0]
plot_floats(init, sigmas, sigmas_2, sigmas_3, target, joint)
